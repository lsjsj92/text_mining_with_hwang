# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.linear_model import LogisticRegression, LinearRegression, Ridge
from sklearn.pipeline import make_pipeline
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('7m_after_prepro.csv')

df2 = data.sample(frac=1).reset_index(drop=True)
print(df2.iloc[0:10,2])
# Out:
# 0    2
# 1    0
# 2    1
# 3    3
# 4    3
# 5    0
# 6    3
# 7    0
# 8    2
# 9    2
# Name: 2, dtype: int64

# %%
X = df2.iloc[:, 1].values
y = df2.iloc[:, 2].values

# %%
X_train_text, X_test_text, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print(len(X_train_text))
print(X_train_text[0])
print(y_train[:10])
# Out:
# 80633
# 라디오스타 조현우 하이라이트 영상 많이 봤 솔직 이미지 원본 엑 스포츠 뉴스 오수정 기자 라디오스타 조현우 자신 하이라이트 영상 많이 봤 솔직 말 했 일 방송 예능 라디오 스타 년 후 제발 특집 까 방 까 방지 획득 주인공 조현우 김영권 이용 이승우 명 월드컵 국가 대표 축구 선수 출연 해 이야기 나눴 이날 조현우 자신 한국 말 자신 소개 했 이어 월드컵 후 근황 대해 하이라이트 영상 대해 언급 했 이 조현우 사실 많이 봤 러시아 봤 솔직 말 해 웃음 자아냈 이용 자신 소개 경기 급소 은 먼저 언급 했 이후 김구라 이용 급소 괜찮 이용 튼튼 자신 는 모습 웃음 자아냈 또 김영원 자신 국민 욕 히어로 됐 독일 전 골 은 재치 언급 해 눈길 그리고 이승우 선수 향해 김구라 이천수 선수 냄새 좋 은 말 했 이승우 역시 이천수 선수 저 굉장히 좋 해 말 했 사진 방송 화면 아이돌 팬 엑 스포츠 뉴스 네이버 엑 스포츠 뉴스 공식 페이스북 트위터 이슈 퀸 엑 스포츠 뉴스 무단 전재 및 배포 금지
# [3 2 1 3 3 1 3 1 2 0]

# %%
pipe = make_pipeline(TfidfVectorizer(min_df=5), LogisticRegression())
param_grid = {
    'logisticregression__C' : [0.001, 0.01, 0.1, 1, 10]
}

grid = GridSearchCV(pipe, param_grid, cv=5)
#print(y_train.shape)
grid.fit(X_train_text, y_train)
print("최상의 교차 검증 점수 : %.2f" %(grid.best_score_))
# Out:
# 최상의 교차 검증 점수 : 0.97

# %%
print(" 테스트 점수 : %.2f" %(grid.score(X_test_text, y_test)))
# Out:
#  테스트 점수 : 0.97

# %%
vector = grid.best_estimator_.named_steps["tfidfvectorizer"]
X_train = vector.transform(X_train_text)
#특성별로 가장 큰 값을 찾는다.
max_value = X_train.max(axis=0).toarray().ravel()
sorted_by_tfidf = max_value.argsort()

#특성 이름을 구한다.

feature_names = np.array(vector.get_feature_names())

print("tfidf가 가장 낮은 특성 20 개 : \n", feature_names[sorted_by_tfidf[:20]])
print("tfidf가 가장 높은 특성 20 개 : \n ", feature_names[sorted_by_tfidf[-20:]])
# Out:
# tfidf가 가장 낮은 특성 20 개 :
#  ['서호경' '암정' '정낭' '마려워' '방광경' '병창' '구자현' '임파' '메디신' '형암' '자빠' '잠열' '정전기력'
#  '홍성범' '최명식' '이은성' '베이더우' '뇌중풍' '커져도' '동남극']
# tfidf가 가장 높은 특성 20 개 :
#   ['김승환' '쉐어링' '맥심' '캐처' '스텔스' '탁현민' '정미홍' '제시카' '공증' '설리' '다이아몬드' '와인' '머크'
#  '포켓몬' '하연수' '프로젝터' '골판지' '김현중' '복권' '티맥스']

# %%
sorted_by_idf = np.argsort(vector.idf_)
print("idf가 가장 낮은 특성 100개 \n", feature_names[sorted_by_idf[:100]])
# Out:
# idf가 가장 낮은 특성 100개
#  ['기자' '금지' '배포' '무단' '전재' '위한' '추가' '오류' '우회' '함수' '뉴스' '이미지' '서울' '원본'
#  '사진' '오후' '밝혔' '한다' '통해' '경제' '다는' '위해' '지난' '저작권자' '페이스북' '바로' '함께' '채널'
#  '이날' '네이버' '대한' '방송' '된다' '한국' '이번' '제보' '진행' '기사' '열린' '제공' '시간' '구독'
#  '공개' '대표' '관련' '가능' '시작' '예정' '모습' '정보' '이후' '대해' '사람' '한편' '참석' '확인'
#  '우리' '이상' '스타' '설명' '라는' '특히' '최근' '정부' '계획' '시장' '자신' '이야기' '미국' '문제'
#  '기업' '관계자' '기술' '상황' '배우' '필요' '모두' '포토' '공식' '러시아' '연합뉴스' '세계' '해야' '다양'
#  '영상' '현재' '언론' '월드컵' '코리아' '국내' '따라' '발표' '오늘' '가장' '결과' '경우' '직접' '그룹'
#  '생각' '대통령']

# %%
print("tfidf가 가장 높은 특성 1000 개 : \n ", feature_names[sorted_by_tfidf[-1000:]])
# Out:
# tfidf가 가장 높은 특성 1000 개 :
#   ['지애' '로또' '윈도' '대영' '이무송' '하현우' '쇼핑' '대탈출' '림프관' '염상' '방제' '부엉이' '화장품'
#  '헬프' '후지필름' '애플' '펜스' '셰프' '화석' '필립스' '수거' '김동현' '크리에이터' '쓰리' '주진우'
#  '박테리아' '보험료' '하석진' '김보성' '노조' '시계' '연희' '이영준' '헤니' '이지영' '송민호' '차명' '카이'
#  '쿠팡' '나연' '에로' '소프트웨어' '함양' '소스' '한충호' '윤승아' '산림' '베트남' '정유미' '노트' '장준하'
#  '시외버스' '레오' '홍지윤' '마일리지' '이다희' '신준섭' '각성' '이동건' '비빔면' '대강' '류상욱' '제습기'
#  '블링' '예천' '김유정' '김미소' '당비' '노치' '새우' '진도' '예산' '근로' '공모주' '취객' '허경환'
#  '유다인' '비앤비' '김구라' '그래핀' '와치' '언서' '청소년' '영풍' '무주' '시인' '승재' '탁재훈' '미우'
#  '아쿠아' '서문탁' '농협' '루나' '마크롱' '필라테스' '난초' '승리' '차현우' '월렛' '모기' '차예련' '하정우'
#  '어비스' '지구' '당사' '조승희' '최동열' '카카오톡' '벤틀리' '전진' '판빙빙' '아드' '빙고' '사료' '우영'
#  '빗소리' '미술관' '잔트' '에티오피아' '혜리' '민수' '이혜원' '이종혁' '서현' '벅스' '에버랜드' '올레드'
#  '이성경' '라멘' '이재룡' '고나은' '인바디' '소방' '독감' '이규형' '산다라박' '송윤아' '바이러스' '박준형'
#  '연금' '이지훈' '준무' '출원' '자전거' '주상욱' '유민주' '도지한' '외통' '창호' '송은이' '바이브' '석탄'
#  '프렌즈' '강지영' '고윤' '빕스' '임현주' '서핑' '태백' '장수' '장신영' '수송기' '급식비' '협동조합' '미라'
#  '난임' '미얀마' '정다은' '경영주' '경제자유구역' '차태현' '듀플렉스' '김용명' '다영' '물류' '이동욱' '이서진'
#  '유준상' '열전' '수출' '리버스' '공매' '동국제강' '코인' '세연' '옥수수' '서울우유' '윤혜진' '주파수'
#  '고성희' '시리' '음악' '호날두' '마르코' '에이수스' '이시영' '심은진' '에일리' '오이' '인공지능' '정준호'
#  '니지' '뉴본' '정읍' '치매' '윤미래' '수시' '마리' '인삼' '박보영' '아우디' '이연희' '바이오' '서리'
#  '특구' '모모' '아이비' '박수진' '필리핀' '김지우' '마녀' '간사' '정인' '보증' '갤럭시' '디바이스' '배윤정'
#  '박민영' '오피스텔' '가네' '제노' '추사랑' '로제' '은행' '결핵' '게임' '법령' '조난자' '논문' '초파리'
#  '오디오' '이준호' '미주' '카풀' '결제' '효광' '이찬오' '흑룡회' '휴양림' '이덕화' '박칼린' '국정원' '스카이'
#  '패션' '최동석' '전준영' '재정' '진진' '삼촌' '서수남' '고양이' '이앙기' '신탁' '외환' '그리스' '홈플러스'
#  '해밀턴' '약초' '울산' '이아현' '준주' '키즈' '휴양소' '도파민' '유아인' '카오스' '텀블러' '토네이도' '재허'
#  '케이스' '핀테크' '재규어' '태블릿' '임원희' '청국장' '식기' '가희' '자본' '철도' '민혁' '혜은이' '선인장'
#  '조현우' '전자서명' '이지우' '장어' '동물' '구글' '경부' '탄자니아' '최자' '김완선' '장윤주' '인견' '박명수'
#  '광고' '테슬라' '스윙스' '이은혜' '캠핑' '유해' '번호판' '나윤' '수용자' '귀촌' '돈스파이크' '김지혜'
#  '이홍기' '대출' '신혜선' '방광' '김원효' '한혜진' '라돈' '벵에돔' '김효진' '김경화' '하이패스' '투사'
#  '가정폭력' '빙붕' '워치' '어스' '요가' '모나코' '투표' '밥솥' '안선영' '김진우' '현금' '찬기' '직위'
#  '연우' '영준' '려욱' '김소희' '아프리카' '대시보드' '네이마르' '손흥민' '필독' '영사기' '하춘화' '라비'
#  '위성' '최은주' '피츠' '두부' '풍운' '신세경' '한화' '서효림' '백일섭' '이국주' '퀄컴' '지코' '수지'
#  '박원숙' '쇼핑백' '배달' '초원' '후기' '페리' '가지급금' '오비' '무아' '카레' '알뜰' '과실' '박보람'
#  '위원장' '취임식' '찜질방' '항균' '달러' '문세윤' '지진' '보험' '단말기' '오지오' '소유진' '왓슨' '앨리스'
#  '탐정' '블랙베리' '남궁민' '이온' '서우' '스카' '과학관' '폭스콘' '이카루스' '인크레더블' '현서' '임수향'
#  '켄타' '기념일' '나이키' '빙수' '슈주' '총영사' '엄현경' '행성' '비투비' '댓글' '김종국' '클로렐라' '이성미'
#  '개미' '요한' '이문식' '김정민' '류준열' '이규성' '라인' '아워홈' '채연' '은하' '지란지교' '코딩' '유이'
#  '장혁' '슈퍼카' '김정현' '가왕' '양평' '원산' '여에스더' '이규복' '효린' '이승훈' '육성재' '도마뱀' '크루즈'
#  '최미' '서은광' '큐리' '스키니' '윤두준' '손희주' '할머니' '헤이즈' '해시드' '러버' '면세점' '갯벌' '박순천'
#  '음료' '김재우' '특활' '골렘' '라이카' '재혼' '이민지' '빨대' '카우스' '거미' '강형욱' '허브' '김희애'
#  '김건모' '백종원' '황지은' '김장미' '코코넛' '개각' '비키니' '김혜진' '남신' '김제동' '사유리' '큐브'
#  '김준현' '로이킴' '강민경' '윤후' '카도' '송다은' '방사선' '볼드윈' '고두심' '게이밍' '이세미' '청하' '종교'
#  '양미라' '루터' '옥택연' '할배' '화웨이' '김우빈' '한샘' '하자드' '레페' '알비' '토스' '소야' '강호'
#  '종현' '구준엽' '마세라티' '뱅킹' '러블리' '하림' '김상중' '박재현' '김향기' '하지원' '미샤' '피처'
#  '하겐다즈' '아이폰' '기한' '특허' '가영' '공룡' '고소영' '토끼' '길림성' '자급' '김원준' '강동호' '영월'
#  '노트북' '애널리스트' '옥주현' '구혜선' '이카' '우도' '검색어' '김부선' '막걸리' '설민석' '전범' '셀바스'
#  '손병호' '동우' '이윤지' '진돗개' '임성빈' '한승연' '서원' '이재영' '파운드리' '넷플릭스' '도당' '오스'
#  '렌탈' '쿠키' '홍윤화' '넷마블' '야마하' '필름' '양념치킨' '이예림' '유성' '토너' '창업' '폭염' '박하선'
#  '처장' '인벤' '케이윌' '함소원' '장근석' '양정원' '커피믹스' '이란' '레이팅' '유호정' '지아' '레디' '택배'
#  '줄리안' '비식' '이규빈' '상표' '육계' '도경완' '민지영' '환전' '레이디' '송아지' '빅토리아' '김창열'
#  '시멘트' '다니엘' '금고' '관광' '박정민' '정다빈' '강민혁' '산업단지' '주택' '고준희' '설계사' '혜박'
#  '박하나' '시안' '임지연' '분양' '메이커스' '레오나르도' '정세운' '박기영' '과학고' '냉면' '박호산' '바비큐'
#  '영장류' '박정수' '강레오' '유빈' '우주' '김윤상' '매매' '치킨' '강경준' '후보' '정은채' '플라스틱' '회전율'
#  '유민' '약사' '예원' '유나' '이완' '태진아' '홍수현' '코어' '송지효' '황인선' '손담비' '박화영' '이근'
#  '홍경민' '아이언' '판사' '안시성' '전경련' '이기우' '먼로' '진서연' '설현' '노홍철' '권혁수' '주스' '신세계'
#  '선풍기' '레이저' '번호' '한채영' '기안' '욕실' '농업' '지스타' '하상욱' '카카오' '그레이' '혜림' '유니티'
#  '위원회' '까마귀' '등록증' '신민아' '우버' '양자' '로봇' '김형자' '슬리피' '자몽' '강소라' '홍진영' '민아'
#  '미드나잇' '건조기' '포스코' '차유람' '티파니' '황보' '도서관' '이선빈' '트로트' '필립' '기촉' '화장실'
#  '김명수' '이현주' '반도체' '버섯' '김희정' '창원' '모하메드' '휴게소' '강승윤' '국적' '오나미' '지중화'
#  '곤약' '제이준' '지점장' '매트리스' '요금제' '규제' '박미선' '강소봉' '샤넬' '구급차' '자니' '김흥국'
#  '이상민' '구미' '업비트' '서유정' '금리' '미스코리아' '타이어' '니콜' '카드' '유세윤' '박중훈' '손나은'
#  '나노' '미분양' '골프장' '체리' '리니지' '유심' '고유진' '박은혜' '연체' '베컴' '김준수' '송승헌' '페트리'
#  '국토연구원' '오랑우탄' '장영란' '최시원' '수자원' '정소민' '동아일보' '이종석' '마리아' '장나라' '타블로'
#  '홍수아' '촉매' '김수로' '스푼' '조세호' '스팀' '현아' '김아중' '강성태' '정해인' '강남' '핵융합' '박광현'
#  '저작물' '변정수' '운석' '인간' '배정남' '기내식' '체크' '예진' '클라우드' '도라에몽' '카지노' '데이터'
#  '콜드' '정음' '전지현' '주유소' '이지혜' '도희' '쌈디' '빙그레' '추성훈' '금연' '김환희' '백신' '미투'
#  '모유' '김치' '자석' '비아이지' '유니' '김도연' '보쉬' '리츠' '미카' '이준기' '김민교' '홍삼' '센서'
#  '부장' '유노윤호' '엠버' '투표소' '홍지민' '스타일러스' '황정음' '홍진경' '남극' '송혜교' '이수경' '선미'
#  '휴가' '금조' '개헌' '황승언' '하리수' '이시언' '김가연' '김아랑' '관사' '이하늬' '장원영' '최재훈' '어도비'
#  '솔비' '데미' '헌혈' '봉태규' '와이브로' '아소' '유선호' '중국어' '정효' '곱창' '박은지' '김수민' '베송'
#  '지이' '다트' '송이우' '카시트' '존박' '이청아' '태연' '공효진' '김승현' '택시' '커브' '올림푸스' '사소'
#  '샤넌' '이경실' '연어' '서지영' '골프' '가정부' '박솔미' '난민' '김지호' '억분' '크리스탈' '천우희' '오존'
#  '에릭남' '솔지' '드론' '스테파니' '윤아' '참치' '한예슬' '송하윤' '최지우' '간미연' '오영주' '루커스'
#  '유채영' '김기수' '칸타' '미자' '이엘리야' '강수정' '박효신' '자이언티' '조용필' '김옥빈' '서유기' '보드게임'
#  '김소현' '신성우' '돌고래' '수학' '모지' '이수민' '박봄' '사무엘' '로꼬' '오디오북' '효민' '서지혜' '메일'
#  '자살' '아이스크림' '전자파' '사카모토' '수박' '민어' '석류' '원빈' '안철수' '한우' '꼰대' '조재현' '티머니'
#  '청원' '스님' '대림' '아론' '박환희' '세리' '각막' '김강우' '김희선' '수봉' '클라라' '펌프' '짱구'
#  '장자연' '홍준표' '이해리' '하만' '유소영' '수소' '진라면' '콰이' '피쳐' '유상무' '서민정' '황우슬혜' '성게'
#  '삼양' '발목' '이유비' '강부자' '맥주' '악취' '레고' '딜런' '펀드' '닭갈비' '비서관' '정진운' '제비'
#  '디비' '보청기' '명태' '산촌' '길드' '박형식' '페이' '이주연' '원전' '손예진' '김사랑' '이미도' '지하수'
#  '케냐' '효성' '대상포진' '피라냐' '이선명' '방용국' '박신혜' '김승환' '쉐어링' '맥심' '캐처' '스텔스'
#  '탁현민' '정미홍' '제시카' '공증' '설리' '다이아몬드' '와인' '머크' '포켓몬' '하연수' '프로젝터' '골판지'
#  '김현중' '복권' '티맥스']
